# %% [markdown]
# ## Polynomial Regrassion

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv('Position_Salaries.csv')

# %%
X=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1].values

# %% [markdown]
# ## Training Linear Regression  model on Training Dataset

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training Polynomial Regression model on whole Dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
reg_2=LinearRegression()
reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression model

# %%
plt.scatter(X,y,color='red')
plt.plot(X,reg.predict(X),color='blue')
plt.title('Truth of bluff (Linear Regression)')
plt.xlabel('Position Label')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Visualising polynomial Regression Model

# %%
plt.scatter(X,y,color='red')
plt.plot(X,reg_2.predict(poly_reg.fit_transform(X)),color='blue')
plt.title('Truth of Bluff (Polynomial Regression)')
plt.xlabel('Position Label')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ## Visualise for higer and smooth surve

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\Cp\AppData\Local\Temp\ipykernel_15448\1885912332.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# ## Predict a new Linear Regression

# %%
reg.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predict a new Polynomial Regression

# %%
reg_2.predict(poly_reg.fit_transform([[6.5]]))
# Out:
# array([158862.45265158])
