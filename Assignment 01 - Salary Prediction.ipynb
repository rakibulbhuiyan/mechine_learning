# %% [markdown]
# # Salary Prediction using Linear Regression

# %%
import pandas as pd 
from matplotlib import pyplot as plt

# %%
dataset=pd.read_csv('Data/Salary Data.csv',sep=',')
dataset
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %% [markdown]
# # EDA

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
dataset.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
plt.scatter(dataset['Experience Years'],dataset['Salary'])
plt.xlabel('Experience Years')
plt.ylabel('Salary')
plt.title('Experience Years vs. Salary')
plt.show()

# %%
import seaborn as sns
sns.histplot(dataset['Salary'], kde=True)
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Distribution of Salary')
plt.show()

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
x=dataset.drop('Experience Years',axis=1)
x.head()
# Out:
#    Salary
# 0   39343
# 1   42774
# 2   46205
# 3   37731
# 4   43525

# %%
y=dataset['Experience Years']
y.head()
# Out:
# 0    1.1
# 1    1.2
# 2    1.3
# 3    1.5
# 4    2.0
# Name: Experience Years, dtype: float64

# %%
plt.scatter(x.mean(),y.mean(),color='red')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=1)

# %%
x_train.head()
# Out:
#     Salary
# 4    43525
# 14   63218
# 10   64445
# 35  105582
# 23   83088

# %%
x_test.head()
# Out:
#     Salary
# 2    46205
# 31  101302
# 3    37731
# 21   67938
# 27   91000

# %%
x.mean()
# Out:
# Salary    74743.625
# dtype: float64

# %%
y.mean()
# Out:
# 5.1525

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Y=mx+c

# %%
m=reg.coef_
m
# Out:
# array([0.00010037])

# %%
c=reg.intercept_
c
# Out:
# -2.349459907846252

# %%
m*3+c
# Out:
# array([-2.3491588])

# %%
m*92000+c
# Out:
# array([6.88450903])

# %%
dataset['predict_salary']=reg.predict(x)
dataset.head()
# Out:
#    Experience Years  Salary  predict_salary
# 0               1.1   39343        1.599367
# 1               1.2   42774        1.943733
# 2               1.3   46205        2.288100
# 3               1.5   37731        1.437571
# 4               2.0   43525        2.019111

# %%
years_experience_12 = np.array([[12]])
years_experience_12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 years_experience_12 = np.array([[12]])
#       2 years_experience_12
#
# NameError: name 'np' is not defined

# %% [markdown]
# # Cost & Lose
